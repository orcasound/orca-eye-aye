# %% [markdown]
# ## Install YOLOv8 and Comet from pip

# %% [markdown]
# we use Comet to visialize the process and result of this project.

# %%
# !pip install ultralytics==8.0.134 comet_ml
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 629.1/629.1 kB 13.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 567.2/567.2 kB 51.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 95.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.8/224.8 kB 26.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.9/137.9 kB 17.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.3/54.3 kB 7.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 512.2/512.2 kB 44.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: websocket-client
#     Found existing installation: websocket-client 1.6.3
#     Uninstalling websocket-client-1.6.3:
#       Successfully uninstalled websocket-client-1.6.3
#   Attempting uninstall: python-box
#     Found existing installation: python-box 7.1.1
#     Uninstalling python-box-7.1.1:
# ...

# %% [markdown]
# ### Initialize Comet with Credientials

# %%
import comet_ml
comet_ml.init(project_name='vesselDetection')

# %% [markdown]
# ## Download some data from roboflow

# %% [markdown]
# install roboflow

# %%
# !pip install roboflow

# %% [markdown]
# On the roboflow website you could find ways to export dataset. Here we are using the download code to get data from roboflow (replace with your own api key):

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="your_apikey")
project = rf.workspace("cuize").project("vesseldetection-dhmgv")
dataset = project.version(17).download("yolov8")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 2.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 8.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 10.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 9.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 37.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 8.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 kB 8.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
#     Uninstalling pyparsing-3.1.1:
#       Successfully uninstalled pyparsing-3.1.1
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.8.1.78
#     Uninstalling opencv-python-headless-4.8.1.78:
#       Successfully uninstalled opencv-python-headless-4.8.1.78
# ...

# %% [markdown]
# ## Train YOLOv8 on the dowloaded dataset

# %%
# !yolo task=detect \
mode=train \
model=yolov8m.pt \
data= /content/vesselDetection_LaJolla-3/data.yaml \
patience =20 \
imgsz=640
# Out:
# New https://pypi.org/project/ultralytics/8.0.190 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.134 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...

# %%
# !yolo task=detect \
mode=train \
model=yolov8m.pt \
data= /content/vesselDetection_LaJolla-4/data.yaml \
patience =20 \
imgsz=640
# Out:
# New https://pypi.org/project/ultralytics/8.0.190 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.134 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="9FKfFVyybJD9PRo1D1DI")
project = rf.workspace("cuize").project("vesseldetection-dhmgv")
dataset = project.version(15).download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Exporting format yolov8 in progress : 85.0%
# Version export complete for yolov8 format
# ...
# Extracting Dataset Version Zip to vesselDetection-15 in yolov8:: 100%|██████████| 5294/5294 [00:00<00:00, 8048.07it/s]

# %%
# !yolo task=detect \
mode=train \
model=yolov8m.pt \
data= /content/vesselDetection-17/data.yaml \
patience =20 \
imgsz=640
# Out:
# New https://pypi.org/project/ultralytics/8.0.190 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.134 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...

# %%
# !yolo task=detect \
mode=train \
model=yolov8m.pt \
data= /content/vesselDetection-17/data.yaml \
epochs = 100 \
patience =20 \
imgsz=640
# Out:
# New https://pypi.org/project/ultralytics/8.0.192 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.134 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...

# %% [markdown]
# **Train yolov8x**

# %%
# !yolo task=detect \
mode=train \
model=yolov8x.pt \
data= /content/vesselDetection-17/data.yaml \
epochs = 200 \
patience =20 \
imgsz=640
# Out:
# ...
# 100% 131M/131M [00:01<00:00, 75.2MB/s]
# New https://pypi.org/project/ultralytics/8.0.192 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.134 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...

# %% [markdown]
# ## Validate on orcasound data

# %%
# !yolo task=detect mode=val model=/content/runs/detect/train5/weights/best.pt data=/content/vesselDetection-14/data.yaml
# Out:
# Ultralytics YOLOv8.0.134 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# Model summary (fused): 218 layers, 25840339 parameters, 0 gradients
# val: Scanning /content/vesselDetection-14/valid/labels.cache... 2641 images, 758 backgrounds, 0 corrupt: 100% 2641/2641 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 166/166 [00:15<00:00, 11.04it/s]
#                    all       2641       2075      0.369      0.224      0.196     0.0932
# Speed: 0.1ms preprocess, 1.7ms inference, 0.0ms loss, 0.6ms postprocess per image
# Results saved to runs/detect/val3

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="9FKfFVyybJD9PRo1D1DI")
project = rf.workspace("cuize").project("vesseldetection_lajolla")
dataset = project.version(4).download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to vesselDetection_LaJolla-4 in yolov8:: 100%|██████████| 307/307 [00:00<00:00, 1412.06it/s]

# %%
# !yolo task=detect \
mode=predict \
model= /content/drive/MyDrive/train2/weights/best.pt \
source= /content/2023_02_02T14m11m56_jpg.rf.1a10cf5ea00e78e4bba14e82b53d1d55.jpg
save_txt = True
# Out:
# Ultralytics YOLOv8.0.134 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25840339 parameters, 0 gradients
#
# image 1/1 /content/2023_02_02T14m11m56_jpg.rf.1a10cf5ea00e78e4bba14e82b53d1d55.jpg: 352x640 2 vessels, 63.1ms
# Speed: 2.3ms preprocess, 63.1ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
# Results saved to runs/detect/predict3

# %%
# !zip -r predict.zip /content/runs/detect/predict
# Out:
#   adding: content/runs/detect/predict/ (stored 0%)
#   adding: content/runs/detect/predict/2023_02_01T11m20m53.jpg (deflated 20%)
#   adding: content/runs/detect/predict/2023_02_01T12m29m51.jpg (deflated 18%)
#   adding: content/runs/detect/predict/2023_02_01T09m08m44.jpg (deflated 25%)
#   adding: content/runs/detect/predict/2023_02_01T13m04m28.jpg (deflated 8%)
#   adding: content/runs/detect/predict/2023_02_01T12m10m25.jpg (deflated 13%)
#   adding: content/runs/detect/predict/2023_02_01T12m53m00.jpg (deflated 13%)
#   adding: content/runs/detect/predict/2023_02_01T10m28m51.jpg (deflated 18%)
#   adding: content/runs/detect/predict/2023_02_01T09m59m04.jpg (deflated 14%)
#   adding: content/runs/detect/predict/2023_02_01T09m38m52.jpg (deflated 18%)
#   adding: content/runs/detect/predict/2023_02_01T16m33m44.jpg (deflated 31%)
#   adding: content/runs/detect/predict/2023_02_01T10m07m23.jpg (deflated 16%)
#   adding: content/runs/detect/predict/2023_02_01T10m16m05.jpg (deflated 16%)
# ...

# %%
import shutil
shutil.move('/content/predict.zip','/content/drive/MyDrive')
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-11-1c646b6e1acc> in <cell line: 2>()
#       1 import shutil
# ----> 2 shutil.move('/content/predict.zip','/content/drive/MyDrive')
#
# /usr/lib/python3.10/shutil.py in move(src, dst, copy_function)
#     812
#     813         if os.path.exists(real_dst):
# --> 814             raise Error("Destination path '%s' already exists" % real_dst)
#     815     try:
#     816         os.rename(src, real_dst)
#
# Error: Destination path '/content/drive/MyDrive/predict.zip' already exists

# %%
from google.colab import files
files.download("/content/predict.zip")
